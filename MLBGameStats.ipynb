# %%
import pandas as pd
from pybaseball import schedule_and_record

# %%
years = [2015, 2016, 2017, 2018, 2019]
teams = ["ATL", "BAL", "CHW", "CIN", "CLE",\
         "DET", "MIL", "MIN", "SDP", "STL", "TEX"]

# %%
data = pd.DataFrame()
for team in teams:
    for year in years:
        d = schedule_and_record(year, team)
        d['Year'] = str(year)
        data = data.append(d, ignore_index=True)

# %%
data.iloc[160:162,:]
# Out:
#                   Date   Tm Home_Away  Opp W/L    R   RA  Inn    W-L  Rank  \
# 160  Sunday, Oct 4 (1)  ATL      Home  STL   W  6.0  0.0  9.0  66-95   4.0
# 161  Sunday, Oct 4 (2)  ATL      Home  STL   W  2.0  0.0  9.0  67-95   4.0
#
#        GB     Win    Loss     Save  Time D/N  Attendance  Streak  \
# 160  23.0  Miller  Lackey     None  2:14   D         NaN     2.0
# 161  23.0  Wisler    Lynn  Jackson  2:19   D     31441.0     3.0
#
#        Orig. Scheduled  Year
# 160               None  2015
# 161  2015-10-03 (Rain)  2015

# %%
adj = data.copy(deep=True)

# %%
adj['DblHdrGm#'] = adj['Date'].apply(lambda row: row[-2] if row[-3] == '(' else 0).astype(int)
adj['DblHdr'] = adj['Date'].apply(lambda row: 1 if row[-3] == '(' else 0).astype(int)
adj['Date'] = adj['Date'].apply(lambda row: row[:-4] if row[-3] == '(' else row)

# %%
adj.iloc[160:162,:]
# Out:
#               Date   Tm Home_Away  Opp W/L    R   RA  Inn    W-L  Rank  ...  \
# 160  Sunday, Oct 4  ATL      Home  STL   W  6.0  0.0  9.0  66-95   4.0  ...
# 161  Sunday, Oct 4  ATL      Home  STL   W  2.0  0.0  9.0  67-95   4.0  ...
#
#        Loss     Save  Time D/N Attendance Streak    Orig. Scheduled  Year  \
# 160  Lackey     None  2:14   D        NaN    2.0               None  2015
# 161    Lynn  Jackson  2:19   D    31441.0    3.0  2015-10-03 (Rain)  2015
#
#     DblHdrGm# DblHdr
# 160         1      1
# 161         2      1
#
# [2 rows x 22 columns]

# %%
adj['Date'] = (adj['Date'] + ' ' + (adj['Year'])).astype('datetime64')

# %%
adj['Year'] = adj['Date'].dt.year
adj['Month'] = adj['Date'].dt.month
adj['Week'] = adj['Date'].dt.week
adj['Day_of_Year'] = adj['Date'].dt.dayofyear
adj['Day_of_Month'] = adj['Date'].dt.day
adj['Day_of_Week'] = adj['Date'].dt.dayofweek
adj['Weekend'] = adj['Day_of_Week'].apply(lambda row: 1 if row in [5,6] else 0)

# %%
adj['Home_Away'] = adj.Home_Away.map({'@':0, 'Home':1})

# %%
adj['Walkoff'] = adj[pd.notnull(adj['W/L'])]['W/L'].apply(lambda row: 1 if len(row) > 1 else 0).astype(int)
adj['W/L'] = adj[pd.notnull(adj['W/L'])]['W/L'].apply(lambda row: 1 if row[0] == 'W' else 0).astype(int)

# %%
adj['Wins'] = adj[pd.notnull(adj['W-L'])]['W-L'].apply(lambda row: row.split('-')[0]).astype(int)
adj['Losses'] = adj[pd.notnull(adj['W-L'])]['W-L'].apply(lambda row: row.split('-')[1]).astype(int)
adj['W-L'] = round(adj['Wins']/(adj['Wins']+adj['Losses']),3)

# %%
adj['Shortened'] = adj[pd.notnull(adj['Inn'])]['Inn'].apply(lambda row: 1 if row < 9 else 0).astype(int)
adj['Extra'] = adj[pd.notnull(adj['Inn'])]['Inn'].apply(lambda row: 1 if row > 9 else 0).astype(int)

# %%
adj['GB'] = adj[pd.notnull(adj['GB'])]['GB'].apply(lambda row: row.split('up')[1] if row.split('up')[0] == ''
                                                   else '-' + row.split('up')[0])
adj['GB'] = adj.GB.replace({'-Tied':0}).astype(float)

# %%
adj['Team_Pitcher'] = adj[pd.notnull(adj['W/L'])].apply(lambda row: row['Win'] if row['W/L'] == 1 else row['Loss'], axis=1)
adj['Opp_Pitcher'] = adj[pd.notnull(adj['W/L'])].apply(lambda row: row['Win'] if row['W/L'] == 0 else row['Loss'], axis=1)

# %%
adj['Duration'] = adj[pd.notnull(adj['Time'])]['Time'].str.split(':').apply(lambda row: (int(row[0])*60)+int(row[1]))

# %%
adj['D/N'] = adj['D/N'].map({'N':0, 'D':1})

# %%
adj['Rescheduled'] = adj[pd.notnull(adj['W/L'])]['Orig. Scheduled'].apply(lambda row: 0 if pd.isnull(row) == True else 1)
adj['Reschedule_Reason'] = adj[adj['Rescheduled'] == 1]['Orig. Scheduled'].apply(lambda row: row[row.find('(')+1:-1])
adj['Orig. Scheduled'] = adj[adj['Rescheduled'] == 1]['Orig. Scheduled'].apply(lambda row: row.split(' (')[0]).astype('datetime64')

# %%
AL = ["BAL","BOS","NYY","TBR","TOR",
      "CHW","CLE","DET","KCR","MIN",
      "HOU","LAA","OAK","SEA","TEX"]
NL = ["ATL","MIA","NYM","PHI","WSN",
      "CHC","CIN","MIL","PIT","STL",
      "ARI","COL","LAD","SDP","SFG"]

def interleague(adj):
    if (adj['Tm'] in AL and adj['Opp'] in AL) or \
       (adj['Tm'] in NL and adj['Opp'] in NL):
        return 0
    else:
        return 1
    
adj['Interleague'] = adj.apply(interleague, axis=1)

# %%
ALE = ["BAL","BOS","NYY","TBR","TOR"]
ALC = ["CHW","CLE","DET","KCR","MIN"]
ALW = ["HOU","LAA","OAK","SEA","TEX"]
NLE = ["ATL","MIA","NYM","PHI","WSN"]
NLC = ["CHC","CIN","MIL","PIT","STL"]
NLW = ["ARI","COL","LAD","SDP","SFG"]

def rival(adj):
    if (adj['Tm'] in ALE and adj['Opp'] in ALE) or \
       (adj['Tm'] in ALC and adj['Opp'] in ALC) or \
       (adj['Tm'] in ALW and adj['Opp'] in ALW) or \
       (adj['Tm'] in NLE and adj['Opp'] in NLE) or \
       (adj['Tm'] in NLC and adj['Opp'] in NLC) or \
       (adj['Tm'] in NLW and adj['Opp'] in NLW):
        return 1
    else:
        return 0
    
adj['Rival'] = adj.apply(rival, axis=1)

# %%
adj['Gm#'] = adj.groupby(['Year','Tm']).cumcount() + 1
adj['HmGm#'] = adj[adj['Home_Away'] == 1].groupby(['Year','Tm']).cumcount() + 1

# %%
adj
# Out:
#            Date   Tm  Home_Away  Opp  W/L     R    RA   Inn    W-L  Rank  ...  \
# 0    2015-04-06  ATL          0  MIA  1.0   2.0   1.0   9.0  1.000   1.0  ...
# 1    2015-04-07  ATL          0  MIA  1.0  12.0   2.0   9.0  1.000   1.0  ...
# 2    2015-04-08  ATL          0  MIA  1.0   2.0   0.0   9.0  1.000   1.0  ...
# 3    2015-04-10  ATL          1  NYM  1.0   5.0   3.0   9.0  1.000   1.0  ...
# 4    2015-04-11  ATL          1  NYM  1.0   5.0   3.0   9.0  1.000   1.0  ...
# 5    2015-04-12  ATL          1  NYM  0.0   3.0   4.0   9.0  0.833   1.0  ...
# 6    2015-04-13  ATL          1  MIA  1.0   3.0   2.0   9.0  0.857   1.0  ...
# 7    2015-04-14  ATL          1  MIA  0.0   2.0   8.0   9.0  0.750   1.0  ...
# 8    2015-04-15  ATL          1  MIA  0.0   2.0   6.0   9.0  0.667   1.0  ...
# 9    2015-04-17  ATL          0  TOR  1.0   8.0   7.0   9.0  0.700   2.0  ...
# 10   2015-04-18  ATL          0  TOR  0.0   5.0   6.0  10.0  0.636   2.0  ...
# 11   2015-04-19  ATL          0  TOR  1.0   5.0   2.0   9.0  0.667   2.0  ...
# 12   2015-04-21  ATL          0  NYM  0.0   1.0   7.0   9.0  0.615   2.0  ...
# 13   2015-04-22  ATL          0  NYM  0.0   2.0   3.0   9.0  0.571   2.0  ...
# 14   2015-04-23  ATL          0  NYM  0.0   3.0   6.0   9.0  0.533   2.0  ...
# 15   2015-04-24  ATL          0  PHI  0.0   0.0   1.0   9.0  0.500   2.0  ...
# 16   2015-04-25  ATL          0  PHI  1.0   5.0   2.0   9.0  0.529   2.0  ...
# 17   2015-04-26  ATL          0  PHI  0.0   4.0   5.0   9.0  0.500   2.0  ...
# 18   2015-04-27  ATL          1  WSN  1.0   8.0   4.0   9.0  0.526   2.0  ...
# 19   2015-04-28  ATL          1  WSN  0.0  12.0  13.0   9.0  0.500   2.0  ...
# 20   2015-04-29  ATL          1  WSN  0.0   4.0  13.0   9.0  0.476   2.0  ...
# 21   2015-04-30  ATL          1  CIN  0.0   1.0   5.0   9.0  0.455   2.0  ...
# 22   2015-05-01  ATL          1  CIN  1.0   4.0   3.0   9.0  0.478   2.0  ...
# 23   2015-05-02  ATL          1  CIN  0.0   4.0   8.0   9.0  0.458   3.0  ...
# 24   2015-05-03  ATL          1  CIN  1.0   5.0   0.0   9.0  0.480   2.0  ...
# 25   2015-05-04  ATL          1  PHI  0.0   2.0   5.0   9.0  0.462   3.0  ...
# 26   2015-05-05  ATL          1  PHI  1.0   9.0   0.0   9.0  0.481   2.0  ...
# 27   2015-05-06  ATL          1  PHI  1.0   7.0   5.0   9.0  0.500   2.0  ...
# 28   2015-05-08  ATL          0  WSN  0.0   2.0   9.0   9.0  0.483   3.0  ...
# 29   2015-05-09  ATL          0  WSN  0.0   6.0   8.0   9.0  0.467   4.0  ...
# ...         ...  ...        ...  ...  ...   ...   ...   ...    ...   ...  ...
# 8876 2019-08-27  TEX          0  LAA  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8877 2019-08-28  TEX          0  LAA  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8878 2019-08-29  TEX          1  SEA  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8879 2019-08-30  TEX          1  SEA  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8880 2019-08-31  TEX          1  SEA  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8881 2019-09-01  TEX          1  SEA  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8882 2019-09-02  TEX          0  NYY  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8883 2019-09-03  TEX          0  NYY  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8884 2019-09-04  TEX          0  NYY  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8885 2019-09-05  TEX          0  BAL  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8886 2019-09-06  TEX          0  BAL  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8887 2019-09-07  TEX          0  BAL  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8888 2019-09-08  TEX          0  BAL  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8889 2019-09-10  TEX          1  TBR  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8890 2019-09-11  TEX          1  TBR  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8891 2019-09-12  TEX          1  TBR  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8892 2019-09-13  TEX          1  OAK  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8893 2019-09-14  TEX          1  OAK  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8894 2019-09-15  TEX          1  OAK  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8895 2019-09-17  TEX          0  HOU  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8896 2019-09-18  TEX          0  HOU  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8897 2019-09-20  TEX          0  OAK  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8898 2019-09-21  TEX          0  OAK  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8899 2019-09-22  TEX          0  OAK  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8900 2019-09-24  TEX          1  BOS  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8901 2019-09-25  TEX          1  BOS  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8902 2019-09-26  TEX          1  BOS  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8903 2019-09-27  TEX          1  NYY  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8904 2019-09-28  TEX          1  NYY  NaN   NaN   NaN   NaN    NaN   NaN  ...
# 8905 2019-09-29  TEX          1  NYY  NaN   NaN   NaN   NaN    NaN   NaN  ...
#
#       Extra Team_Pitcher  Opp_Pitcher Duration Rescheduled  Reschedule_Reason  \
# 0       0.0      Teheran      Alvarez    156.0         0.0                NaN
# 1       0.0         Wood        Latos    194.0         0.0                NaN
# 2       0.0      Cunniff      Koehler    165.0         0.0                NaN
# 3       0.0      Johnson      Montero    181.0         0.0                NaN
# 4       0.0      Teheran          Gee    145.0         0.0                NaN
# 5       0.0        Jaime        Colon    157.0         0.0                NaN
# 6       0.0       Miller        Latos    182.0         0.0                NaN
# 7       0.0       Cahill      Koehler    180.0         0.0                NaN
# 8       0.0       Stults        Haren    145.0         0.0                NaN
# 9       0.0       Martin        Cecil    189.0         0.0                NaN
# 10      1.0      Marimon        Cecil    161.0         0.0                NaN
# 11      0.0       Miller       Norris    161.0         0.0                NaN
# 12      0.0       Cahill        Niese    161.0         0.0                NaN
# 13      0.0      Johnson      Carlyle    154.0         0.0                NaN
# 14      0.0      Teheran        Colon    198.0         0.0                NaN
# 15      0.0      Johnson        Giles    154.0         0.0                NaN
# 16      0.0       Miller     Buchanan    147.0         0.0                NaN
# 17      0.0       Cahill     Williams    158.0         0.0                NaN
# 18      0.0       Stults       Fister    188.0         0.0                NaN
# 19      0.0       Grilli      Treinen    206.0         0.0                NaN
# 20      0.0         Wood   Zimmermann    167.0         0.0                NaN
# 21      0.0       Miller        Leake    142.0         0.0                NaN
# 22      0.0  Foltynewicz   DeSclafani    156.0         0.0                NaN
# 23      0.0       Stults      Marquis    154.0         0.0                NaN
# 24      0.0      Teheran        Cueto    151.0         0.0                NaN
# 25      0.0         Wood       Harang    188.0         0.0                NaN
# 26      0.0       Miller  Billingsley    143.0         0.0                NaN
# 27      0.0  Foltynewicz     Williams    187.0         0.0                NaN
# 28      0.0       Stults     Gonzalez    141.0         0.0                NaN
# 29      0.0       Martin       Storen    192.0         0.0                NaN
# ...     ...          ...          ...      ...         ...                ...
# 8876    NaN          NaN          NaN      NaN         NaN                NaN
# 8877    NaN          NaN          NaN      NaN         NaN                NaN
# 8878    NaN          NaN          NaN      NaN         NaN                NaN
# 8879    NaN          NaN          NaN      NaN         NaN                NaN
# 8880    NaN          NaN          NaN      NaN         NaN                NaN
# 8881    NaN          NaN          NaN      NaN         NaN                NaN
# 8882    NaN          NaN          NaN      NaN         NaN                NaN
# 8883    NaN          NaN          NaN      NaN         NaN                NaN
# 8884    NaN          NaN          NaN      NaN         NaN                NaN
# 8885    NaN          NaN          NaN      NaN         NaN                NaN
# 8886    NaN          NaN          NaN      NaN         NaN                NaN
# 8887    NaN          NaN          NaN      NaN         NaN                NaN
# 8888    NaN          NaN          NaN      NaN         NaN                NaN
# 8889    NaN          NaN          NaN      NaN         NaN                NaN
# 8890    NaN          NaN          NaN      NaN         NaN                NaN
# 8891    NaN          NaN          NaN      NaN         NaN                NaN
# 8892    NaN          NaN          NaN      NaN         NaN                NaN
# 8893    NaN          NaN          NaN      NaN         NaN                NaN
# 8894    NaN          NaN          NaN      NaN         NaN                NaN
# 8895    NaN          NaN          NaN      NaN         NaN                NaN
# 8896    NaN          NaN          NaN      NaN         NaN                NaN
# 8897    NaN          NaN          NaN      NaN         NaN                NaN
# 8898    NaN          NaN          NaN      NaN         NaN                NaN
# 8899    NaN          NaN          NaN      NaN         NaN                NaN
# 8900    NaN          NaN          NaN      NaN         NaN                NaN
# 8901    NaN          NaN          NaN      NaN         NaN                NaN
# 8902    NaN          NaN          NaN      NaN         NaN                NaN
# 8903    NaN          NaN          NaN      NaN         NaN                NaN
# 8904    NaN          NaN          NaN      NaN         NaN                NaN
# 8905    NaN          NaN          NaN      NaN         NaN                NaN
#
#       Interleague  Rival  Gm#  HmGm#
# 0               0      1    1    NaN
# 1               0      1    2    NaN
# 2               0      1    3    NaN
# 3               0      1    4    1.0
# 4               0      1    5    2.0
# 5               0      1    6    3.0
# 6               0      1    7    4.0
# 7               0      1    8    5.0
# 8               0      1    9    6.0
# 9               1      0   10    NaN
# 10              1      0   11    NaN
# 11              1      0   12    NaN
# 12              0      1   13    NaN
# 13              0      1   14    NaN
# 14              0      1   15    NaN
# 15              0      1   16    NaN
# 16              0      1   17    NaN
# 17              0      1   18    NaN
# 18              0      1   19    7.0
# 19              0      1   20    8.0
# 20              0      1   21    9.0
# 21              0      0   22   10.0
# 22              0      0   23   11.0
# 23              0      0   24   12.0
# 24              0      0   25   13.0
# 25              0      1   26   14.0
# 26              0      1   27   15.0
# 27              0      1   28   16.0
# 28              0      1   29    NaN
# 29              0      1   30    NaN
# ...           ...    ...  ...    ...
# 8876            0      1  133    NaN
# 8877            0      1  134    NaN
# 8878            0      1  135   66.0
# 8879            0      1  136   67.0
# 8880            0      1  137   68.0
# 8881            0      1  138   69.0
# 8882            0      0  139    NaN
# 8883            0      0  140    NaN
# 8884            0      0  141    NaN
# 8885            0      0  142    NaN
# 8886            0      0  143    NaN
# 8887            0      0  144    NaN
# 8888            0      0  145    NaN
# 8889            0      0  146   70.0
# 8890            0      0  147   71.0
# 8891            0      0  148   72.0
# 8892            0      1  149   73.0
# 8893            0      1  150   74.0
# 8894            0      1  151   75.0
# 8895            0      1  152    NaN
# 8896            0      1  153    NaN
# 8897            0      1  154    NaN
# 8898            0      1  155    NaN
# 8899            0      1  156    NaN
# 8900            0      0  157   76.0
# 8901            0      0  158   77.0
# 8902            0      0  159   78.0
# 8903            0      0  160   79.0
# 8904            0      0  161   80.0
# 8905            0      0  162   81.0
#
# [8906 rows x 42 columns]

# %%
adj.dtypes
# Out:
# Date                 datetime64[ns]
# Tm                           object
# Home_Away                     int64
# Opp                          object
# W/L                         float64
# R                           float64
# RA                          float64
# Inn                         float64
# W-L                         float64
# Rank                        float64
# GB                          float64
# Win                          object
# Loss                         object
# Save                         object
# Time                         object
# D/N                         float64
# Attendance                  float64
# Streak                      float64
# Orig. Scheduled      datetime64[ns]
# Year                          int64
# DblHdrGm#                     int64
# DblHdr                        int64
# Month                         int64
# Week                          int64
# Day_of_Year                   int64
# Day_of_Month                  int64
# Day_of_Week                   int64
# Weekend                       int64
# Walkoff                     float64
# Wins                        float64
# Losses                      float64
# Shortened                   float64
# Extra                       float64
# Team_Pitcher                 object
# Opp_Pitcher                  object
# Duration                    float64
# Rescheduled                 float64
# Reschedule_Reason            object
# Interleague                   int64
# Rival                         int64
# Gm#                           int64
# HmGm#                       float64
# dtype: object

# %%
# adj.to_csv('MLBGameStats.csv', index=False)

# %%
# import saspy

# %%
# mysas = saspy.SASsession(cfgname='iomwin')

# %%
# mysas.df2sd(adj,table='MLB_GAME_STATS',libref="lcssan")
